# %%
import pandas as pd

data = pd.Series([23.4,54.3,34.5,9.0,22.3])
print(data)
data.mean()
data.sum()
type(data)
# Out:
# 0    23.4
# 1    54.3
# 2    34.5
# 3     9.0
# 4    22.3
# dtype: float64
# pandas.core.series.Series

# %%
mixed = pd.Series([23.4,54.3,34.5,9.0,22.3,'a','b','c'])
print(mixed)
# Out:
# 0    23.4
# 1    54.3
# 2    34.5
# 3     9.0
# 4    22.3
# 5       a
# 6       b
# 7       c
# dtype: object

# %%
data.describe()
# Out:
# count     5.000000
# mean     28.700000
# std      16.927345
# min       9.000000
# 25%      22.300000
# 50%      23.400000
# 75%      34.500000
# max      54.300000
# dtype: float64

# %%
meta =data.describe()
meta['50%']
# Out:
# 23.4

# %%
data[2]
# Out:
# 34.5

# %%
raw =[23.4,54.3,34.5,9.0,22.3]
data = pd.Series(raw,index=['M','T','W','R','F'])
data
# Out:
# M    23.4
# T    54.3
# W    34.5
# R     9.0
# F    22.3
# dtype: float64

# %%
data['W']
# Out:
# 34.5

# %%
data = pd.Series({'Mon':23.4,'Tue':54.3,'Wed':34.5,'Thu':9.0,'Fri':22.3})
print(data)
# Out:
# Mon    23.4
# Tue    54.3
# Wed    34.5
# Thu     9.0
# Fri    22.3
# dtype: float64

# %%
grades_dict = {'Wally': [87, 96, 70], 'Eva': [100, 87, 90],
            'Sam': [94, 77, 90], 'Katie': [100, 81, 82],
            'Bob': [83, 65, 85]}
print(grades_dict)
# Out:
# {'Wally': [87, 96, 70], 'Eva': [100, 87, 90], 'Sam': [94, 77, 90], 'Katie': [100, 81, 82], 'Bob': [83, 65, 85]}

# %%
grades = pd.DataFrame(grades_dict)
print(grades)
# Out:
#    Wally  Eva  Sam  Katie  Bob
# 0     87  100   94    100   83
# 1     96   87   77     81   65
# 2     70   90   90     82   85

# %%
grades = pd.DataFrame(grades_dict, index=['T1','T2','T3'])
print(grades)
# Out:
#     Wally  Eva  Sam  Katie  Bob
# T1     87  100   94    100   83
# T2     96   87   77     81   65
# T3     70   90   90     82   85

# %%
grades.T
# Out:
#         T1  T2  T3
# Wally   87  96  70
# Eva    100  87  90
# Sam     94  77  90
# Katie  100  81  82
# Bob     83  65  85

# %%
grades
# Out:
#     Wally  Eva  Sam  Katie  Bob
# T1     87  100   94    100   83
# T2     96   87   77     81   65
# T3     70   90   90     82   85

# %%
grades[['Eva','Wally']]
# Out:
#     Eva  Wally
# T1  100     87
# T2   87     96
# T3   90     70

# %%
grades.iloc[]
# Out:
#   Cell In[18], line 1
#     grades.iloc[]
#                 ^
# SyntaxError: invalid syntax

# %%
grades.mean(axis=0)
grades.mean(axis=1)
# Out:
# T1    92.8
# T2    81.2
# T3    83.4
# dtype: float64

# %%
grades['Avg'] = grades.mean(axis=1)
grades
# Out:
#     Wally  Eva  Sam  Katie  Bob   Avg
# T1     87  100   94    100   83  92.8
# T2     96   87   77     81   65  81.2
# T3     70   90   90     82   85  83.4

# %%
grades['SK_Avg'] = (grades.Sam + grades.Katie) / 2
grades
# Out:
#     Wally  Eva  Sam  Katie  Bob   Avg  SK_Avg
# T1     87  100   94    100   83  92.8    97.0
# T2     96   87   77     81   65  81.2    79.0
# T3     70   90   90     82   85  83.4    86.0

# %%
grades.T.T1
# Out:
# Wally      87.0
# Eva       100.0
# Sam        94.0
# Katie     100.0
# Bob        83.0
# Avg        92.8
# SK_Avg     97.0
# Name: T1, dtype: float64

# %%
grades2 = grades.T
grades2
# Out:
#            T1    T2    T3
# Wally    87.0  96.0  70.0
# Eva     100.0  87.0  90.0
# Sam      94.0  77.0  90.0
# Katie   100.0  81.0  82.0
# Bob      83.0  65.0  85.0
# Avg      92.8  81.2  83.4
# SK_Avg   97.0  79.0  86.0

# %%
grades2.concat({'T1':50, 'T2':60,'T3':70},index ="Test")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 grades2.concat({'T1':50, 'T2':60,'T3':70},index ="Test")
#
# File /opt/anaconda3/envs/ds/lib/python3.10/site-packages/pandas/core/generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'concat'

# %%
grades2[(grades2.T2 >= 80) | (grades2.T3 >= 80.0)]
# Out:
#            T1    T2    T3
# Wally    87.0  96.0  70.0
# Eva     100.0  87.0  90.0
# Sam      94.0  77.0  90.0
# Katie   100.0  81.0  82.0
# Bob      83.0  65.0  85.0
# Avg      92.8  81.2  83.4
# SK_Avg   97.0  79.0  86.0
